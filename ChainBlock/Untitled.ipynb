# %%
#!/usr/bin/env python
# coding: utf-8

# In[2]:
# In[1]:


import tweepy
import time
import webbrowser


# In[2]:


access_token = '2712395911-ehqFfEGiM5COVQg149vqT5miIcvM8SorJmchg0N'
access_token_secret = 'K9GuOkmrf1PuwUjUA7lblH3KGotsvIev4vvyYtGxu9Wd0'
consumer_key = 'LKi9NfPzoRzF7Ha54SAd9bezO'
consumer_secret = 'PO6jkanwHnPltE9umZtTFnElEJ9GSWuxpso3SsEixg5mH3tMf2'


# In[3]:


ACCESS_TOKEN = '2712395911-iuFwRZCt2Q2GlptqQY3GKAadaSDXy0dNr5DZtQq'
ACCESS_SECRET = 'OUPZxFtXW8g7IdSTzX5a6Ib5HjscrZgt1s7kfdjALzpu4'
CONSUMER_KEY = 'AYw8duD2eqWRXN6utsfbYRgDl'
CONSUMER_SECRET = 'NzLMSEzpnHwkabi3GsOM8Vx2U5WkLVWxjmML1IDAVGHp2bzVi6'
bearer_token='AAAAAAAAAAAAAAAAAAAAAPIXbgEAAAAAOfvRG%2B7YjOXHyR%2FqcFmPeXX8WNA%3D9C5LjlxUKCI89RRCZ7NQPra4zL0NDEs9mIOvj9BM73JhGXZFtB'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)


# In[4]:


callback_uri= 'oob'
# If the authentication was successful, this should print the
# screen name / username of the account
print(api.verify_credentials().screen_name)


# In[5]:


auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET,callback_uri)
redirect_url = auth.get_authorization_url()
print(redirect_url)
_id = "103770785"
user = api.get_user(user_id=_id)


# In[6]:


webbrowser.open(redirect_url)
try:
    redirect_url = auth.get_authorization_url()
except tweepy.TweepError:
    print('Error! Failed to get request token.')


# In[7]:


user_pin_input = input("What is the pin value? ")
#public_tweets = api.home_timeline()
#for tweet in public_tweets:
#    print(tweet.text)


# In[8]:


auth.get_access_token(user_pin_input)
user = api.get_user(screen_name='NFT_Kaneki')
print(user.id)


# In[9]:


print(auth.access_token,auth.access_token_secret)
print(user.screen_name)
print(user.followers_count)
for friend in user.friends():
   print(friend.screen_name)#Amount of followers


# In[10]:


api = tweepy.API(auth)


# In[11]:


#will not work without elevated access from twitter
#me = api.get_user()
#print(me.screen_name)


# In[12]:


#Must use client if you only have essential access
client = tweepy.Client(consumer_key=CONSUMER_KEY,
                       consumer_secret=CONSUMER_SECRET,
                       access_token=ACCESS_TOKEN,
                       access_token_secret=ACCESS_SECRET)


# In[13]:



#response = client.create_tweet(text='hello world')

#print(response)


# In[14]:


client = tweepy.Client(bearer_token=bearer_token)

# Replace User ID
id = '44196397'

tweets = client.get_liked_tweets(id=id, tweet_fields=['context_annotations','created_at','geo'])

for tweet in tweets.data:
    print(tweet)


# In[15]:


#nft tweet and shows all users who retweeted the tweet
id = '1519300117265801216'
users = client.get_retweeters(id=id, user_fields=['profile_image_url'])

for user in users.data:
    print(user)


# In[16]:


# mute a user
id = '1354481209187856385'
result = client.mute(target_user_id=user.id)
print(f"user muted? {result.data['muting']}")
api.create_block(screen_name='NFT_Kaneki')
# Out:
# dungeonex
# ---------------------------------------------------------------------------
# TokenRequestDenied                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tweepy\auth.py in _get_request_token(self, access_type)
#      61                 url += f'?x_auth_access_type={access_type}'
# ---> 62             return self.oauth.fetch_request_token(url)
#      63         except Exception as e:
#
# ~\anaconda3\lib\site-packages\requests_oauthlib\oauth1_session.py in fetch_request_token(self, url, realm, **request_kwargs)
#     286         self._client.client.realm = " ".join(realm) if realm else None
# --> 287         token = self._fetch_token(url, **request_kwargs)
#     288         log.debug("Resetting callback_uri and realm (not needed in next phase).")
#
# ~\anaconda3\lib\site-packages\requests_oauthlib\oauth1_session.py in _fetch_token(self, url, **request_kwargs)
#     368             error = "Token request failed with code %s, response was '%s'."
# --> 369             raise TokenRequestDenied(error % (r.status_code, r.text), r)
#     370
#
# TokenRequestDenied: Token request failed with code 401, response was '{"errors":[{"code":32,"message":"Could not authenticate you."}]}'.
#
# During handling of the above exception, another exception occurred:
#
# TweepyException                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tweepy\auth.py in get_authorization_url(self, signin_with_twitter, access_type)
#      75                 url = self._get_oauth_url('authorize')
# ---> 76             self.request_token = self._get_request_token(
#      77                 access_type=access_type
#
# ~\anaconda3\lib\site-packages\tweepy\auth.py in _get_request_token(self, access_type)
#      63         except Exception as e:
# ---> 64             raise TweepyException(e)
#      65
#
# TweepyException: Token request failed with code 401, response was '{"errors":[{"code":32,"message":"Could not authenticate you."}]}'.
#
# During handling of the above exception, another exception occurred:
#
# TweepyException                           Traceback (most recent call last)
# <ipython-input-1-7a985cb93a3f> in <module>
#      47
#      48 auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET,callback_uri)
# ---> 49 redirect_url = auth.get_authorization_url()
#      50 print(redirect_url)
#      51 _id = "103770785"
#
# ~\anaconda3\lib\site-packages\tweepy\auth.py in get_authorization_url(self, signin_with_twitter, access_type)
#      79             return self.oauth.authorization_url(url)
#      80         except Exception as e:
# ---> 81             raise TweepyException(e)
#      82
#      83     def get_access_token(self, verifier=None):
#
# TweepyException: Token request failed with code 401, response was '{"errors":[{"code":32,"message":"Could not authenticate you."}]}'.
